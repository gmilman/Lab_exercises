# %%
# git PAT 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

import requests
import PIL
import random

# %%
help(requests)
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# DESCRIPTION
#     Requests HTTP Library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings.
#     Basic GET usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> b'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('https://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key1": "value1",
#            "key2": "value2"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <https://requests.readthedocs.io>.
#
#     :copyright: (c) 2017 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# ...

# %%
response = requests.get (' https://xkcd.com')

# %%
response.status_code
# Out:
# 200

# %%
response.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '3039', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Tue, 24 Jan 2023 05:08:14 GMT', 'ETag': 'W/"63cf67be-1e2f"', 'Expires': 'Wed, 25 Jan 2023 03:56:40 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Via': '1.1 varnish, 1.1 varnish', 'Accept-Ranges': 'bytes', 'Date': 'Wed, 25 Jan 2023 11:51:39 GMT', 'Age': '248', 'X-Served-By': 'cache-dfw-kdfw8210070-DFW, cache-cdg20781-CDG', 'X-Cache': 'HIT, HIT', 'X-Cache-Hits': '9, 1', 'X-Timer': 'S1674647499.218177,VS0,VE1', 'Vary': 'Accept-Encoding'}

# %%
response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# ...

# %%
response.headers['Expires']
# Out:
# 'Wed, 25 Jan 2023 03:56:40 GMT'

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>\n<title>xkcd: Lane Change Highway</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>\n<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>\n<!-- <script type="text/javascript" src="/s/b66ed7.js" async></script>\n<script type="text/javascript" src="/s/1b9456.js" async></script> -->\n\n<meta property="og:site_name" content="xkcd">\n\n<meta property="og:title" content="Lane Change Highway">\n<meta property="og:url" content="https://xkcd.com/2728/">\n<meta property="og:image" content="https://imgs.xkcd.com/comics/lane_change_highway_2x.png">\n<meta name="twitter:card" content="summary_large_image">\n\n</head>\n<body>\n<di
# ...

# %%
### Andy's solution
random_number = random.randint(0,100)
url = f"https://xkcd.com/{random_number}/info.0.json"
response = requests.get(url)
#results = response.json();
#print(response.text)
# GM: want to return the 'img' key value to then save and show image

# from URL above, create dictionary and extract the url for the image file 
#(as url above is for website and thus image cannot be saved)
xkcd_dict=json.loads(response.text)
image_url=xkcd_dict["img"]
image_retrieval= requests.get(image_url)
image=image_retrieval.content


#saves to directory with image number
with open (f'xkcd_{random_number}.jpg','wb') as f:
    f.write(image)

IP.display.Image(image)

## you cant save this or download it as an image as url is referring to the webpage

# %%
## adapted by gemma
random_number = random.randint(0,100)
url = f'https://xkcd.com/{random_number}/'
response = requests.get(url)
response.status_code
image_data = response.content



with open('comics.png','wb') as f:
    f.write(image_data)
response.status_code
print(url)
# Out:
# https://xkcd.com/68/

# %%
import json

# %%
r=response.text
r
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>\n<title>xkcd: Five Thirty</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>\n<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>\n<!-- <script type="text/javascript" src="/s/b66ed7.js" async></script>\n<script type="text/javascript" src="/s/1b9456.js" async></script> -->\n\n<meta property="og:site_name" content="xkcd">\n\n<meta property="og:title" content="Five Thirty">\n<meta property="og:url" content="https://xkcd.com/68/">\n<meta property="og:image" content="https://imgs.xkcd.com/comics/">\n<meta name="twitter:card" content="summary_large_image">\n\n</head>\n<body>\n<div id="topContainer">\n<div id="topLeft">\n<u
# ...

# %%
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# ...

# %%
from PIL import Image
from io import BytesIO
image = Image.open(BytesIO(image_data))
image.show()
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23636\2628693575.py in <module>
#       1 from PIL import Image
#       2 from io import BytesIO
# ----> 3 image = Image.open(BytesIO(image_data))
#       4 image.show()
#       5
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    3145     for message in accept_warnings:
#    3146         warnings.warn(message)
# -> 3147     raise UnidentifiedImageError(
#    3148         "cannot identify image file %r" % (filename if filename else fp)
#    3149     )
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x00000226FB143F40>

# %%
import IPython as IP

# %%
IP.display.Image(response.content)

# %%
### soultion that works that gives an image based on web address
image_URL='https://imgs.xkcd.com/comics/grownups.png'
IPython.display.Image(image_URL)

# %%
img_data = requests.get(image_URL).content
with open('Lab_13_image.png', 'wb') as handler:
    handler.write(img_data)

# %%
img.save('C:\\Users\\gemma\\Documents\\IronHack\\Lab_exercises\\img.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23636\680472642.py in <module>
# ----> 1 img.save('C:\\Users\\gemma\\Documents\\IronHack\\Lab_exercises\\img.png')
#
# AttributeError: 'Image' object has no attribute 'save'

# %%
### challenge 2

response = requests.get('https://httpbin.org/get')

# %%
response.text
# Out:
# '{\n  "args": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.28.1", \n    "X-Amzn-Trace-Id": "Root=1-63d24e50-02c6d8fb58d7acd01ba740f3"\n  }, \n  "origin": "185.146.221.98", \n  "url": "https://httpbin.org/get"\n}\n'

# %%
response.headers
# Out:
# {'Date': 'Thu, 26 Jan 2023 09:56:32 GMT', 'Content-Type': 'application/json', 'Content-Length': '312', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
response.content
# Out:
# b'{\n  "args": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.28.1", \n    "X-Amzn-Trace-Id": "Root=1-63d24e50-02c6d8fb58d7acd01ba740f3"\n  }, \n  "origin": "185.146.221.98", \n  "url": "https://httpbin.org/get"\n}\n'

# %%
parameters = {'things':2,'total':25}

# %%
ploads = {"username": "u", "password": "p"}
response = requests.post("https://httpbin.org/post", params=parameters, data=ploads)

Dictionary= response.json()['form']
print(Dictionary)
# Out:
# {'password': 'p', 'username': 'u'}

# %%
# challeng 3 
## for infor; https://docs.github.com/en/rest?apiVersion=2022-11-28
###notes from senjiia

req.get api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack... query
resp.json
search
>>>  items
[item['name'] for item in search ['itemns']]
repos.files.sort()

 dictionary of item url{item[name]; item[url] for e}
then do for request for get
reuest.content

import base64

[base64.b64code(b64messar).decode('ascii') for b64message in request.content]
# Out:
#   File "C:\Users\gemma\AppData\Local\Temp\ipykernel_24820\2694062139.py", line 5
#     req.get api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack... query
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# The filenames of the secret files contain `.scavengerhunt` an
# d they are scattered in different directories of this repo. The secret files are named from `.0001.scavengerhunt` to `.0024.scavengerhunt`. They are scattered randomly throughout this repo. You need to **search for these files by calling the Github API**, not searching the local files on your computer.

# %%
repo_url = 'https://github.com/ironhack-datalabs/scavenger'
# https://api.github.com/search/labels?repository_id=REPOSITORY_ID&q=Q

response= requests.get('https://api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack-datalabs/scavanger')
    
#q_parameters = {'scavengerhunt' in : path }

#https://api.github.com/search/code?q=addClass+repo:jquery/jquery+filename:classes.js

response.status_code
#response.text
# Out:
# 422

# %%
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack-datalabs/scavenger')
response=response.json()
print(response)
# Out:
# {'total_count': 24, 'incomplete_results': False, 'items': [{'name': '.0016.scavengerhunt', 'path': '47222/.0016.scavengerhunt', 'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0', 'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', 'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0', 'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt', 'repository': {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=', 'name': 'scavenger', 'full_name': 'ironhack-datalabs/scavenger', 'private': False, 'owner': {'login': 'ironhack-datalabs', 'id': 44225188, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4', 'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ironhack-datalabs', 'html_url': 'https://github
# ...

# %%
# pull out files names as a list

filenames= [item['name'] for item in response['items'] ]
 # or 
filenames =[]
dict_name_url= {}
for file in response['items']:
    filenames.append(file['name'])
    dict_name_url[file['name']]=file['url']

#sort list in ascending order
filenames.sort()
print(filenames)
print(dict_name_url)

# %%
#sort dictionary

sort_dict= {key:val for key, val in sorted(dict_name_url.items(), key = lambda ele: ele[0])}
print(sort_dict)
# Out:
# {'.0001.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/98750/.0001.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', '.0002.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/88596/.0002.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', '.0003.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/60224/.0003.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', '.0004.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/68848/.0004.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', '.0005.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/44639/.0005.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', '.0006.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/15024/.0006.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', '.0007.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/17020/
# ...

# %%
joke=''
for name in sort_dict:
    response= requests.get(sort_dict[name])
    print(response.content)

import base64

[base64.b64code(b64messar).decode('ascii') for b64message in requests.content]
# Out:
# b'{"name":".0001.scavengerhunt","path":"98750/.0001.scavengerhunt","sha":"2add7632f1323136324efbf38ec66db1838b6173","size":3,"url":"https://api.github.com/repos/ironhack-datalabs/scavenger/contents/98750/.0001.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476","html_url":"https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/98750/.0001.scavengerhunt","git_url":"https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/2add7632f1323136324efbf38ec66db1838b6173","download_url":"https://raw.githubusercontent.com/ironhack-datalabs/scavenger/9308ccc8a4c34c5e3a991ee815222a9691c32476/98750/.0001.scavengerhunt","type":"file","content":"SW4K\\n","encoding":"base64","_links":{"self":"https://api.github.com/repos/ironhack-datalabs/scavenger/contents/98750/.0001.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476","git":"https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/2add7632f1323136324efbf38ec66db1838b6173","htm
# ...

# %%
SENJIAAS RESPONSE
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack-datalabs/scavenger')
search = response.json()
search

search["items"]






2:47
repo_files_names = [item["name"] for item in search["items"]]
repo_files_names.sort()
repo_files_names
2:48
repo_files_urls = {item["name"]: item["url"] for item in search["items"]}
repo_files_urls
2:52
repo_files = [requests.get(repo_files_urls[repo_filename]) for repo_filename in repo_files_names]
repo_files
2:53
repo_files_content = [file.json()["content"] for file in repo_files]
repo_files_content
2:53
import base64
message = [base64.b64decode(b64message).decode('ascii') for b64message in repo_files_content]
message
